# %% [markdown]
# ## Data Prep

# %%
# Import package
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.style.use('ggplot')
import warnings
warnings.filterwarnings('ignore')

# Set up file directory
dir_data = 'C:\\Users\\victo\\Dropbox\\AI_M\\data_p1'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
app_train.head()
# Out:
# Path of read in data: C:\Users\victo\Dropbox\AI_M\data_p1\application_train.csv
#    SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0      100002       1         Cash loans           M            N
# 1      100003       0         Cash loans           F            N
# 2      100004       0    Revolving loans           M            Y
# 3      100006       0         Cash loans           F            N
# 4      100007       0         Cash loans           M            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               Y             0          202500.0    406597.5      24700.5
# 1               N             0          270000.0   1293502.5      35698.5
# 2               Y             0           67500.0    135000.0       6750.0
# 3               Y             0          135000.0    312682.5      29686.5
# 4               Y             0          121500.0    513000.0      21865.5
#
# ...

# %% [markdown]
# ## Visualizae "HOUSETYPE_MODE" and "AMT_CREDIT" Histogram

# %%
yy = app_train[['HOUSETYPE_MODE', 'AMT_CREDIT']]
print(yy['HOUSETYPE_MODE'].value_counts())

print(yy.shape)# Identify missing value and Nas
# Out:
# block of flats      150503
# specific housing      1499
# terraced house        1212
# Name: HOUSETYPE_MODE, dtype: int64
# (307511, 2)

# %%
## Remove Na
yy = yy.dropna()
yy.head()
# Out:
#     HOUSETYPE_MODE  AMT_CREDIT
# 0   block of flats    406597.5
# 1   block of flats   1293502.5
# 12  block of flats     80865.0
# 13  block of flats    918468.0
# 14  block of flats    773680.5

# %%
unique_house_type = np.sort(yy['HOUSETYPE_MODE'].unique())

nrows = len(unique_house_type)
ncols = nrows // 2

plt.figure(figsize=(10,30))
for i in range(len(unique_house_type)):
    plt.subplot(nrows, ncols, i+1)
    yy.loc[yy['HOUSETYPE_MODE'] == unique_house_type[i], 'AMT_CREDIT'].hist()
    plt.title(str(unique_house_type[i]))
plt.show()
