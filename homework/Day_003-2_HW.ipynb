# %% [markdown]
# ## Manipulate txt data

# %% [markdown]
# #### Read txt file

# %%
## Read from Internet
import requests
link = "https://raw.githubusercontent.com/vashineyu/slides_and_others/master/tutorial/examples/imagenet_urls_examples.txt"
f = requests.get(link)
print(f.text)
# Out:
# n00015388_157	http://farm1.static.flickr.com/145/430300483_21e993670c.jpg
# n00015388_238	http://farm2.static.flickr.com/1005/3352960681_37b9c1d27b.jpg
# n00015388_304	http://farm1.static.flickr.com/27/51009336_a9663af3dd.jpg
# n00015388_327	http://farm4.static.flickr.com/3025/2444687979_bf7bc8df21.jpg
# n00015388_355	http://img100.imageshack.us/img100/3253/forrest004fs9.jpg
# n00015388_373	http://img172.imageshack.us/img172/4606/napo03072en9.jpg
# n00015388_379	http://fotootjesvanannelies.web-log.nl/olifantfotootjes/images/2008/06/04/img_8870.jpg
# n00015388_388	http://www.deweekkrant.nl/images/library/pictures/4f/2e/a5/cf/2_3d81b762a5e8a345bbb1f0884fab2e9762146129.jpg
# n00015388_442	http://www.porschemania.it/discus/messages/815/102099.jpg
# n00015388_474	http://farm1.static.flickr.com/72/225029238_805b0937ca.jpg
# n00015388_514	http://farm2.static.flickr.com/1128/1432436038_6c131f1bb0.jpg
# n00015388_671	http://farm4.static.flickr.com/3217/2942611930_d68204f726.jpg
# ...

# %%
## Read from directory
import numpy as np
import pandas as pd

df = pd.read_table("C:\\Users\\victo\\Dropbox\\AI_M\\data_p1\\urls.txt", delim_whitespace=True, names=('pic_name', 'url'),
                   dtype={'pic_name': np.str, 'url': np.str})

df = pd.DataFrame(df)
print(df.head())
# Out:
#         pic_name                                                url
# 0  n00015388_157  http://farm1.static.flickr.com/145/430300483_2...
# 1  n00015388_238  http://farm2.static.flickr.com/1005/3352960681...
# 2  n00015388_304  http://farm1.static.flickr.com/27/51009336_a96...
# 3  n00015388_327  http://farm4.static.flickr.com/3025/2444687979...
# 4  n00015388_355  http://img100.imageshack.us/img100/3253/forres...

# %% [markdown]
# #### Read the first five images in df data frame

# %%
from PIL import Image
from io import BytesIO
import numpy as np
import matplotlib.pyplot as plt

# %%
def img2arr_fromURLs(url_list, resize = False):
    img_list = []
    i = 0
    j = 0
    while i < 5:
        link = url_list[j]
        try:
            response = requests.get(link)
            img_list.append(Image.open(BytesIO(response.content)))
        except:
            print('Image Index {} doesn\'t exist'.format(j))
        else:
            i += 1
        finally:
            j += 1
    return img_list

# %%
result = img2arr_fromURLs(df.iloc[:,1].values)
print("Total images that we got: %i " % len(result)) # 如果不等於 5, 代表有些連結失效囉

for im_get in result:
    plt.imshow(im_get)
    plt.show()
# Out:
# Image Index 4 doesn't exist
# Image Index 5 doesn't exist
# Image Index 6 doesn't exist
# Image Index 7 doesn't exist
# Image Index 8 doesn't exist
# Total images that we got: 5
